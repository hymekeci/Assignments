# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
kill = pd.read_csv("PoliceKillingsUS.csv")

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.shape
# Out:
# (2535, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
np.array(kill.manner_of_death.unique())
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
# with seaborn
sns.boxplot(x='gender', y='age', hue='manner_of_death',data=kill)
plt.show()

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
# with seaborn
plt.figure(figsize=(7,5))
sns.swarmplot(data=kill, x='gender', y='age', hue='manner_of_death')
plt.show()

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
dangerous_cities = kill.city.value_counts().head(12)
dangerous_cities
# Out:
# Los Angeles     39
# Phoenix         31
# Houston         27
# Chicago         25
# Las Vegas       21
# San Antonio     20
# Columbus        19
# Austin          18
# Miami           18
# St. Louis       15
# Indianapolis    14
# Tucson          14
# Name: city, dtype: int64

# %%
dangerous_cities_index = dangerous_cities.index
dangerous_cities_index
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Las Vegas',
#        'San Antonio', 'Columbus', 'Austin', 'Miami', 'St. Louis',
#        'Indianapolis', 'Tucson'],
#       dtype='object')

# %%
# with seaborn barplot
plt.figure(figsize=(8,5))
sns.barplot(x=dangerous_cities_index, y= dangerous_cities)
plt.xticks(rotation= 45)
plt.title('Most Dangerous Cities', color='b', fontsize= 16)
plt.show()

# %%
# with seaborn countplot
plt.figure(figsize=(8,5))
sns.countplot(x='city', order= dangerous_cities_index, data=kill)
plt.xticks(rotation= 45)
plt.title('Most Dangerous Cities', color='b', fontsize= 16)
plt.show()

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
dangerous_state = kill.state.value_counts().head(20)
dangerous_state
# Out:
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# PA     51
# NM     51
# AL     50
# VA     47
# NY     45
# SC     44
# Name: state, dtype: int64

# %%
dangerous_state_index = dangerous_state.index
dangerous_state_index
# Out:
# Index(['CA', 'TX', 'FL', 'AZ', 'OH', 'OK', 'CO', 'GA', 'NC', 'MO', 'IL', 'WA',
#        'TN', 'LA', 'PA', 'NM', 'AL', 'VA', 'NY', 'SC'],
#       dtype='object')

# %%
# with seaborn barplot
plt.figure(figsize=(8,5))
sns.barplot(x=dangerous_state_index, y=dangerous_state)
plt.xticks(rotation = 45)
plt.title('Most Dangerous States', fontsize=16, color='b')
plt.show()

# %%
# with seaborn countplot
plt.figure(figsize=(8,5))
sns.barplot( x=dangerous_state_index, y=dangerous_state)
plt.xticks(rotation = 45)
plt.title('Most Dangerous States', fontsize=16, color='b')
plt.show()

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
illness_count = kill.signs_of_mental_illness.value_counts()
illness_count
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
illness_count_index = illness_count.index
illness_count_index
# Out:
# Index([False, True], dtype='object')

# %%
# with seaborn
sns.barplot(x= illness_count_index, y = illness_count);

# %%
sns.countplot(kill.signs_of_mental_illness);

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
threat_count = kill.threat_level.value_counts()
threat_count
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
threat_count_index = threat_count.index
threat_count_index
# Out:
# Index(['attack', 'other', 'undetermined'], dtype='object')

# %%
# with seaborn
#sns.countplot(kill.threat_level)
sns.barplot(x = threat_count_index, y= threat_count)
plt.xlabel('threat_level')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
flee_count = kill.flee.value_counts()
flee_count
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
flee_count_index = flee_count.index
flee_count_index
# Out:
# Index(['Not fleeing', 'Car', 'Foot', 'Other'], dtype='object')

# %%
# with seaborn
#sns.countplot(kill.flee);
sns.barplot(x = flee_count_index, y = flee_count)
plt.xlabel('flee')
plt.ylabel('count')
plt.show()

# %% [markdown]
# Out of Subject

# %%
fig, ax = plt.subplots()
sns.countplot(data = kill, x= kill.flee, hue = 'threat_level')
ax.set_title('Flee Types For Gender', color = 'b', fontsize = 14)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.03, p.get_height()+10));
